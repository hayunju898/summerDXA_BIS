# %%
#multiple regression model

import pandas as pd
from sklearn import linear_model

data = pd.read_csv('/Users/yunjuha/Desktop/SROP/DXA_BIS_Project/2023-06-23_DXA_BIS_data.csv')
selected_columns = ['RA1PRAGE', 'RA1PRSEX', 'RA1PF7A', 'tRA4PBMI', 'tRA4IALM', 'tRA4IALMbyHt2', 'tRA4IALMbyBMI', 'tRA4IcorE2I', 'tRA4IALMbyE2I', 'tRA4ILLM', 'tRA4ILegE2I', 'tRA4ILLMbyLE2Icor', 'RA4IMaxGrip', 'tRA4IMaxGrip', 'RA4DRAWJPOWO', 'tRA4DRAWJPOWO']
subset_df = pd.DataFrame(data[selected_columns])

# %%
#Handgrip Strength
#separating the predictors (X) and the target variable (y)

df = subset_df.dropna(subset = ['RA1PRAGE', 'RA1PRSEX', 'RA1PF7A', 'tRA4PBMI', 'tRA4IALM', 'tRA4IALMbyHt2', 'tRA4IALMbyBMI', 'tRA4IcorE2I', 'tRA4IALMbyE2I', 'tRA4ILLM', 'tRA4ILegE2I', 'tRA4ILLMbyLE2Icor', 'tRA4IMaxGrip'])

X = df[['RA1PRAGE', 'RA1PRSEX', 'RA1PF7A', 'tRA4PBMI', 'tRA4IALM', 'tRA4IALMbyHt2', 'tRA4IALMbyBMI', 'tRA4IcorE2I', 'tRA4IALMbyE2I', 'tRA4ILLM', 'tRA4ILegE2I', 'tRA4ILLMbyLE2Icor']]
y = df[['tRA4IMaxGrip']]

regr = linear_model.LinearRegression()
regr.fit(X, y)

#print(regr.coef_)

# Add a constant term to the predictors (X) matrix
X = sm.add_constant(X)

# Fit the multiple regression model
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           tRA4IMaxGrip   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     21.39
# Date:                Sat, 24 Jun 2023   Prob (F-statistic):           4.07e-31
# Time:                        14:21:00   Log-Likelihood:                -267.31
# No. Observations:                 240   AIC:                             560.6
# Df Residuals:                     227   BIC:                             605.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -18.8046     16.455     -1.143      0.254     -51.229      13.620
# ...

# %%
#Jump Power
#separating the predictors (X) and the target variable (y)

df = subset_df.dropna(subset = ['RA1PRAGE', 'RA1PRSEX', 'RA1PF7A', 'tRA4PBMI', 'tRA4IALM', 'tRA4IALMbyHt2', 'tRA4IALMbyBMI', 'tRA4IcorE2I', 'tRA4IALMbyE2I', 'tRA4ILLM', 'tRA4ILegE2I', 'tRA4ILLMbyLE2Icor', 'tRA4DRAWJPOWO'])

X = df[['RA1PRAGE', 'RA1PRSEX', 'RA1PF7A', 'tRA4PBMI', 'tRA4IALM', 'tRA4IALMbyHt2', 'tRA4IALMbyBMI', 'tRA4IcorE2I', 'tRA4IALMbyE2I', 'tRA4ILLM', 'tRA4ILegE2I', 'tRA4ILLMbyLE2Icor']]
y = df[['tRA4DRAWJPOWO']]

regr = linear_model.LinearRegression()
regr.fit(X, y)

#print(regr.coef_)

# Add a constant term to the predictors (X) matrix
X = sm.add_constant(X)

# Fit the multiple regression model
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          tRA4DRAWJPOWO   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     99.00
# Date:                Sat, 24 Jun 2023   Prob (F-statistic):           4.75e-83
# Time:                        14:21:52   Log-Likelihood:                 124.41
# No. Observations:                 240   AIC:                            -222.8
# Df Residuals:                     227   BIC:                            -177.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                11.5435      3.217      3.588      0.000       5.204      17.883
# ...
